# %%
import numpy as np

# Charger le tenseur
tensor = np.load("persuasion_tensor_3d.npy")

print("Tenseur chargé avec succès ✅")
print("Type :", type(tensor))
print("Shape :", tensor.shape)
print("Nombre total de valeurs :", tensor.size)
